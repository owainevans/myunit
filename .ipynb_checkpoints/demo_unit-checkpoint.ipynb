# %% [markdown]
# ## Demos of Venture Unit

# %%
# %%vl
# [clear]
# [assume coin (* .1 (beta 1 1) ) ]
# [assume x (flip coin) ]
# [observe x true ]
# [observe (flip coin) true ]

# %%
# %%unit
# [assume loc (normal 0. 100.)]
# [assume m1 (normal loc 3.)]
# [assume x11 (normal m1 .3)]
# [assume x12 (normal m1 .3)]

# %%
# %%unit run
# [assume loc (normal 0. 100.)]
# [assume m1 (normal loc 3.)]
# [assume m2 (normal loc 3.)]
# [assume x11 (normal m1 .3)]
# [assume x12 (normal m1 .3)]
# [assume x13 (normal m1 .3)]
# [assume x14 (normal m1 .3)]
# [assume x21 (normal m2 .3)]
# [assume x22 (normal m2 .3)]
# [observe x11 1.]
# [observe x12 1.]
# [observe x13 1.]
# [observe x14 1.]
# [observe x21 5.]
# [observe x22 5.]

# %%
# %%unit kl:(200,300,4)
# [assume loc (normal 0. 100.)]
# [assume m1 (normal loc 3.)]
# [assume x11 (normal m1 .3)]
# [assume x12 (normal m1 .3)]
# [observe x11 1.]
# [observe x12 1.]

# %%
model_instance = _

# %%
cond_hist = model_instance.runFromConditional(120,runs=2,verbose=False)

# %%
cond_hist.plot(no_histograms=1,no_flat_series=1)

# %%
cond_hist_long = model_instance.runFromConditional(250,runs=5,verbose=False)

# %% [markdown]
# ## Useful Features of Magic Commands

# %%
# Supress output!
np.random.poisson(1,1000);

# %%
# %%bash
# echo 'hello'
# echo 'gulp' >&2
# echo 'burble' >&3
# Out:
# hello
# gulp

# %%
# %%writefile gulp.sh
# echo 'hello'
# echo 'gulp' >&2
# Out:
# Writing gulp.sh

# %%
# !./gulp.sh
# Out:
# hello
# gulp

# %% [markdown]
# Example of calling bash on program specified as string. will print lines at specified time.

# %%
# %%script --bg --out bashout bash -c "while read line; do echo $line; sleep 1; done"
# line 1
# line 2
# line 3
# line 4
# line 5
# Out:
# Starting job # 2 in a separate thread.

# %%
import time
tic = time.time()
line = True
while True:
    line = bashout.readline()
    if not line:
        break
    sys.stdout.write("%.1fs: %s" %(time.time()-tic, line))
    sys.stdout.flush()

# %% [markdown]
# # Unit with multiple Explanations

# %% [markdown]
# ---PLAN:
# Run same model on multiple ripls. Extract time series on some variable and combine on a single plot. Also plot the series of the individual RIPLS.

# %%
import vent_magic_play, time
#  RECALL that ripl generation is slow coz of cxx bug

# %%
ip=get_ipython()
load_ipython_extension(ip)
# %reload_ext vent_magic_play

# %%
# %%unit 100
# [assume loc (normal 0. 30.)]
# [assume m1 (normal loc 3.)]
# [assume x11 (normal m1 .3)]
# [assume x12 (normal m1 .3)]
# [assume x13 (normal m1 10)]
# [observe x11 20.]
# [observe x12 20.]
# [observe x13 20.]
# Out:
# using 100 explanations
# [<vent_magic_play.MyModelClass instance at 0x2ac00a8c>,
#  <vent_magic_play.MyModelClass instance at 0x118b02cc>,
#  <vent_magic_play.MyModelClass instance at 0x22dc416c>,
#  <vent_magic_play.MyModelClass instance at 0x1daa4f2c>,
#  <vent_magic_play.MyModelClass instance at 0x1329e46c>,
#  <vent_magic_play.MyModelClass instance at 0x1836dfcc>,
#  <vent_magic_play.MyModelClass instance at 0x1836d5cc>,
#  <vent_magic_play.MyModelClass instance at 0x23fe5cac>,
#  <vent_magic_play.MyModelClass instance at 0x167948cc>,
#  <vent_magic_play.MyModelClass instance at 0x241b928c>,
#  <vent_magic_play.MyModelClass instance at 0x24341fcc>,
#  <vent_magic_play.MyModelClass instance at 0x1836d66c>,
#  <vent_magic_play.MyModelClass instance at 0x2468784c>,
#  <vent_magic_play.MyModelClass instance at 0x245b104c>,
#  <vent_magic_play.MyModelClass instance at 0x245b108c>,
#  <vent_magic_play.MyModelClass instance at 0x24a841cc>,
#  <vent_magic_play.MyModelClass instance at 0x24b6be8c>,
#  <vent_magic_play.MyModelClass instance at 0x24b6f04c>,
#  <vent_magic_play.MyModelClass instance at 0x24c4778c>,
#  <vent_magic_play.MyModelClass instance at 0x24dc4fec>,
#  <vent_magic_play.MyModelClass instance at 0x24b6f02c>,
#  <vent_magic_play.MyModelClass instance at 0x2512cb0c>,
#  <vent_magic_play.MyModelClass instance at 0xcf0bbac>,
#  <vent_magic_play.MyModelClass instance at 0x253970ac>,
#  <vent_magic_play.MyModelClass instance at 0x2546d9ac>,
#  <vent_magic_play.MyModelClass instance at 0x2547ffac>,
#  <vent_magic_play.MyModelClass instance at 0x256eea4c>,
#  <vent_magic_play.MyModelClass instance at 0x25867a2c>,
#  <vent_magic_play.MyModelClass instance at 0x25955c6c>,
#  <vent_magic_play.MyModelClass instance at 0x25955c8c>,
#  <vent_magic_play.MyModelClass instance at 0x255ec32c>,
#  <vent_magic_play.MyModelClass instance at 0x25ca6fac>,
#  <vent_magic_play.MyModelClass instance at 0x25e2826c>,
#  <vent_magic_play.MyModelClass instance at 0x25f1808c>,
#  <vent_magic_play.MyModelClass instance at 0x25f1802c>,
#  <vent_magic_play.MyModelClass instance at 0x25f1804c>,
#  <vent_magic_play.MyModelClass instance at 0x25f1806c>,
#  <vent_magic_play.MyModelClass instance at 0x263e31ac>,
#  <vent_magic_play.MyModelClass instance at 0x26560c2c>,
#  <vent_magic_play.MyModelClass instance at 0x2656502c>,
#  <vent_magic_play.MyModelClass instance at 0x2663676c>,
#  <vent_magic_play.MyModelClass instance at 0x26727fcc>,
#  <vent_magic_play.MyModelClass instance at 0x2689fa4c>,
#  <vent_magic_play.MyModelClass instance at 0x26b23aec>,
#  <vent_magic_play.MyModelClass instance at 0x26c0c4ec>,
#  <vent_magic_play.MyModelClass instance at 0x26d8e7ec>,
#  <vent_magic_play.MyModelClass instance at 0x26e747cc>,
#  <vent_magic_play.MyModelClass instance at 0x26e5f98c>,
#  <vent_magic_play.MyModelClass instance at 0x270de94c>,
#  <vent_magic_play.MyModelClass instance at 0x271c9a0c>,
#  <vent_magic_play.MyModelClass instance at 0x2734752c>,
#  <vent_magic_play.MyModelClass instance at 0x27347fac>,
#  <vent_magic_play.MyModelClass instance at 0x27347fec>,
#  <vent_magic_play.MyModelClass instance at 0x2769a62c>,
#  <vent_magic_play.MyModelClass instance at 0x2778b24c>,
#  <vent_magic_play.MyModelClass instance at 0x2790806c>,
#  <vent_magic_play.MyModelClass instance at 0x2790802c>,
#  <vent_magic_play.MyModelClass instance at 0x2790804c>,
#  <vent_magic_play.MyModelClass instance at 0x27aca18c>,
#  <vent_magic_play.MyModelClass instance at 0x27dd818c>,
#  <vent_magic_play.MyModelClass instance at 0x27ec3aec>,
#  <vent_magic_play.MyModelClass instance at 0x27fb1f0c>,
#  <vent_magic_play.MyModelClass instance at 0x2813088c>,
#  <vent_magic_play.MyModelClass instance at 0x2811cfac>,
#  <vent_magic_play.MyModelClass instance at 0x28219fcc>,
#  <vent_magic_play.MyModelClass instance at 0x284849ec>,
#  <vent_magic_play.MyModelClass instance at 0x286014cc>,
#  <vent_magic_play.MyModelClass instance at 0x286ebc6c>,
#  <vent_magic_play.MyModelClass instance at 0x287da7ac>,
#  <vent_magic_play.MyModelClass instance at 0x287c696c>,
#  <vent_magic_play.MyModelClass instance at 0x28a4292c>,
#  <vent_magic_play.MyModelClass instance at 0x28bc3dcc>,
#  <vent_magic_play.MyModelClass instance at 0x28ca752c>,
#  <vent_magic_play.MyModelClass instance at 0x28ca7f8c>,
#  <vent_magic_play.MyModelClass instance at 0x28ca7fcc>,
#  <vent_magic_play.MyModelClass instance at 0x2900060c>,
#  <vent_magic_play.MyModelClass instance at 0x2917b22c>,
#  <vent_magic_play.MyModelClass instance at 0x2926e08c>,
#  <vent_magic_play.MyModelClass instance at 0x2926e02c>,
#  <vent_magic_play.MyModelClass instance at 0x2926e04c>,
#  <vent_magic_play.MyModelClass instance at 0x294bd16c>,
#  <vent_magic_play.MyModelClass instance at 0x2926e06c>,
#  <vent_magic_play.MyModelClass instance at 0x297340ac>,
#  <vent_magic_play.MyModelClass instance at 0x298e1f0c>,
#  <vent_magic_play.MyModelClass instance at 0x2964ceac>,
#  <vent_magic_play.MyModelClass instance at 0x2994208c>,
#  <vent_magic_play.MyModelClass instance at 0x29a2d7cc>,
#  <vent_magic_play.MyModelClass instance at 0x29ca652c>,
#  <vent_magic_play.MyModelClass instance at 0x2994204c>,
#  <vent_magic_play.MyModelClass instance at 0x29f09b4c>,
#  <vent_magic_play.MyModelClass instance at 0x2a089ecc>,
#  <vent_magic_play.MyModelClass instance at 0x29ca2e8c>,
#  <vent_magic_play.MyModelClass instance at 0x2a24a9ec>,
#  <vent_magic_play.MyModelClass instance at 0x2a25afec>,
#  <vent_magic_play.MyModelClass instance at 0x2a4c9a8c>,
#  <vent_magic_play.MyModelClass instance at 0x2a64a48c>,
#  <vent_magic_play.MyModelClass instance at 0x2a7365cc>,
#  <vent_magic_play.MyModelClass instance at 0x2a736d6c>,
#  <vent_magic_play.MyModelClass instance at 0x2a3c836c>,
#  <vent_magic_play.MyModelClass instance at 0x2aa84fec>]

# %%
start = time.time()
models = _
no_ripls = len(models)

no_sweeps = 40
hists = [model.runFromConditional(sweeps=no_sweeps, runs=1) for model in models]
print 'series for each chain:', hists[0].nameToSeries.keys()
print 'time per sweep',(time.time() - start)/no_sweeps
# Out:
# series for each chain: ['loc', 'sweep_iters', 'logscore', 'm1', 'sweep_time', 'x11', 'x12', 'x13']
# time per sweep 4.62096462846

# %%
# create a dict, with key for each variable in history, that aggregates the histories of each chain

agg_series = {  key:zeros((no_ripls,no_sweeps) )  for key in hists[0].nameToSeries.keys() }

for var_name in agg_series.keys():
    for count,history in enumerate(hists):
        agg_series[var_name][count,:] = history.nameToSeries[var_name][0].values

# %%
def plot_variable(ax,agg_series,var_name,no_sweeps,no_ripls,subset=False):
    x=arange(no_sweeps)
    limit = 8  if subset else no_ripls    
    for i in range(limit):
        ax.plot(x,agg_series[var_name][i,:])

fig,ax = subplots()
plot_variable(ax,agg_series,'loc',no_sweeps,no_ripls,subset=True)

# %%
var_names = ['logscore','m1']
fig,ax = subplots(ncols=len(var_names),sharex=True,figsize=(12,5) )
for var_name in var_names:
    plot_variable(var_name
for i,var_name in enumerate(agg_series):
    if i < (len(agg_series)-3): 
        for j in range(no_ripls):
            ax[i].plot(x,agg_series[var_name][j,:],label='R'+str(j))
        ax[i].legend()
        ax[i].set_title(var_name)

# %%
agg_means = mean(agg_series,axis=0)
print agg_means[ range(0,no_sweeps,5) ]
# Out:
# [-8.85799492 -6.74614221 -6.31352318 -5.23627325 -3.10761794 -0.76312126
#  -2.05001516 -2.47389816  0.10534005  0.39111311  1.51104766  0.97084095
#   1.1512336   1.86097444  0.88391358  1.68406158]

# %%
from scipy.stats import kde



agg_histo = [0] * no_sweeps
for i in range(no_sweeps):
    agg_histo[i] = histogram(agg_series['loc'][:,i])
    if i%20==0: hist(agg_series['loc'][:,i],bins=30)

# %%
from scipy.stats import kde

xr = linspace(-100,100,1000)
points = 4
fig,ax = subplots()

for i in range(no_sweeps):
    if i%(no_sweeps/points)==0 or i==no_sweeps:
        pdf= kde.gaussian_kde(agg_series['loc'][:,i])
        ax.plot(xr,pdf(xr),label='sweep '+str(i))
ax.legend()

# %%
kde.gaussian_kde?

# %%
# %%unit 4
# [assume x (beta 1 1)]
# [assume y (flip x) ]
# Out:
# ERROR: Cell magic `%%unit` not found.
