# %% [markdown]
# # MRipl Map CRP Demo

# %%
for i in range(10):
    # %v [predict i]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-96b44df9c690> in <module>()
#       1 for i in range(10):
# ----> 2     get_ipython().magic(u'v [predict i]')
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2170         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2171         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2172         return self.run_line_magic(magic_name, magic_arg_s)
#    2173
#    2174     #-------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2091                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2092             with self.builtin_trap:
# -> 2093                 result = fn(*args,**kwargs)
#    2094             return result
#    2095
#
# <string> in v(self, line, cell)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     189     # but it's overkill for just that one bit of state.
#     190     def magic_deco(arg):
# --> 191         call = lambda f, *a, **k: f(*a, **k)
#     192
#     193         if callable(arg):
#
# /home/owainevans/.config/ipython/profile_default/startup/venturemagics.py in v(self, line, cell)
#      76         if cell is None:
#      77
# ---> 78             venture_outs = ipy_ripl.execute_instruction( str(line), params=None )
#      79
#      80             directives = ipy_ripl.list_directives()
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction_string, params)
#      63         try:
#      64             # execute instruction, and handle possible exception
# ---> 65             ret_value = self.sivm.execute_instruction(parsed_instruction)
#      66         except VentureException as e:
#      67             # all exceptions raised by the Sivm get augmented with a
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction)
#      61                 f = getattr(self,'_do_'+instruction_type)
#      62                 return f(instruction)
# ---> 63             return self._call_core_sivm_instruction(instruction)
#      64
#      65     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     100             desugared_src_location['expression_index'] = new_index
#     101         try:
# --> 102             response = self.core_sivm.execute_instruction(desugared_instruction)
#     103         except VentureException as e:
#     104             if e.exception == "evaluation":
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      42         utils.validate_instruction(instruction,self._implemented_instructions)
#      43         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 44         return f(instruction)
#      45
#      46     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_predict(self, instruction)
#      72         exp = utils.validate_arg(instruction,'expression',
#      73                 utils.validate_expression,modifier=_modify_expression, wrap_exception=False)
# ---> 74         did, val = self.engine.predict(exp)
#      75         return {"directive_id":did, "value":_parse_value(val)}
#      76
#
# /usr/local/lib/python2.7/dist-packages/venture/cxx/engine.pyc in predict(self, datum)
#      53   def predict(self,datum):
#      54     baseAddr = self.nextBaseAddr()
# ---> 55     self.trace.eval(baseAddr,self.desugarLambda(datum))
#      56
#      57     self.directives[self.directiveCounter] = ["predict",datum]
#
# RuntimeError: unidentifiable C++ exception

# %%
# load script which contains MRipl class on loads IPython Magic

# in terminal: ipcluster start --n=2
# %run [YOUR PATH]/Venturecxx/python/lib/venturemagics/ip_parallel.py
# %run ~/Venturecxx/python/lib/venturemagics/ip_parallel.py
clear_all_engines()

import numpy as np

prog='''
[assume alpha (uniform_continuous .01 1)]
[assume crp (make_crp alpha) ]
[assume z (mem (lambda (i) (crp) ) ) ]
[assume mu (mem (lambda (z dim) (normal 0 5) ) ) ] 
[assume sig (mem (lambda (z dim) (uniform_continuous .1 8) ) ) ]
[assume x (mem (lambda (i dim) (normal (mu (z i) dim) (sig (z i) dim)))  ) ]'''

## create MRipl with two ripls and load program
v=MRipl(2)
v.execute_program(prog)

# create and plot x0 and x1 observations
n=30 
nor = np.random.normal
x0 = list(nor(0,1,n/2)) + list(nor(5,1,n/2))
x1 = list(nor(0,1,n/2)) + list(nor(5,1,n/2))
scatter(x0,x1,c=([0]*(n/2) + [1]*(n/2)),s=25,marker='+')

# give MRipl and observe for each datapoint
[v.observe( '(x %i 0)' % i, str(x0[i]), label=( 'x_%i0' % i) ) for i in range(len(x0))];
[v.observe( '(x %i 1)' % i, str(x1[i]), label=( 'x_%i1' % i) ) for i in range(len(x1))];

v.infer(1400)
# Out:
# ['(pid, index, seed)', (8530, 0, 0), (8533, 0, 1)]
# [None, None]

# %%
# %%mr_map v crp_plot store_result
# # nb: the result will automatically be stored as store_result
#
# # add n variable to the namespace of the engines
# n=30
# import os
# pid = os.getpid()
#
# # define a function that takes a single ripl as input: the
# # cell magic will map it across all the ripls
#
# def crp_plot(ripl):
#     # plot the current values for the cluster membership for each datapoint
#     x0 = [ripl.sample( '(x %i 0)' % i ) for i in range(n) ]
#     x1 = [ripl.sample( '(x %i 1)' % i ) for i in range(n) ]
#     zs = [ripl.sample('(z %i)' % i) for i in range(n) ]
#     fig,ax = plt.subplots(2,sharex=True,sharey=True,figsize=(10,7))
#     ax[0].scatter(x0,x1,c=zs ,s=30,marker='+')
#     ax[0].set_title('Current inference for z values (Engine pid: %i)' % pid )
#
#     # generate some new data from the current state of the Markov chain
#     px0 = [ripl.predict( '(x %i 0)' % i ) for i in range(n,2*n) ]
#     px1 = [ripl.predict( '(x %i 1)' % i ) for i in range(n,2*n) ]
#     pzs = [ripl.predict('(z %i)' % i) for i in range(n,2*n) ]
#     ax[1].scatter(x0+px0,x1+px1,c=zs+pzs,s=30,marker='+')
#     ax[1].set_title('X-values sampled from current state of inference (Engine pid: %i)' % pid )
#     return zs[:5]
# Out:
# [output:0]
# [output:1]
# store_result =
# {'info': {'mripl': 'v', 'proc': 'crp_plot'},
#  'out': [[3, 3, 3, 3, 3], [1, 1, 1, 1, 1]]}

# %%
# To use %%mr_map we need to have the code for the procedure 
# we wish to map. In contrast, the function mr_map_nomagic
# takes a procedure as an argument. The limitation is that 
# the procedure must not be a closure.
# %px import collections

def mean_plot(ripl):
    x0 = [ripl.sample( '(x %i 0)' % i ) for i in range(n) ]
    x1 = [ripl.sample( '(x %i 1)' % i ) for i in range(n) ]
    zs = [ripl.sample('(z %i)' % i) for i in range(n) ]
    mu_0 = [ripl.sample('(mu %i 0)' % i ) for i in range(n) ]
    mu_1 = [ripl.sample('(mu %i 1)' % i ) for i in range(n) ]
    z_t = collections.Counter(zs).most_common()[0][0]
    mu_0_t,mu_1_t = mu_0[z_t], mu_1[z_t]
    
    sig_0 = [ripl.sample('(sig %i 0)' % i ) for i in range(n) ]
    sig_1 = [ripl.sample('(sig %i 1)' % i ) for i in range(n) ]
    sig_0_t,sig_1_t = sig_0[z_t], sig_1[z_t]
    el_0,el_1 = [mu_0_t]*2, [mu_1_t]*2
    
    
    fig,ax = plt.subplots()
    ax.scatter(x0,x1,c=zs ,s=30,marker='+')
    ax.scatter(mu_0_t,mu_1_t ,s=50,marker='o')

mr_map_nomagic(v,mean_plot)
# Out:
# [output:0]
# [output:1]
# {'info': {'mripl': 'mripl_0', 'proc': 'user_proc_1063140873'},
#  'out': [None, None]}
