# %%
# %run /home/owainevans/Venturecxx/python/lib/venturemagics/ip_parallel.py
clear_all_engines()
v=MRipl(2)
# Out:
# ['(pid, index, seed)', (8530, 0, 0), (8533, 0, 1)]

# %%
# %%mr_map v foo
# def foo(r):
#     plt.scatter(range(10),range(10))
# Out:
# [output:0]
# [output:1]
# {'info': {'mripl': 'v', 'proc': 'foo'}, 'out': [None, None]}

# %%
# %px import numpy as np
def fool(r):
    beta = np.random.beta
    plt.scatter(beta(.3,.3,30),beta(.3,.3,30))
mr_map_nomagic(v,fool)
# Out:
# [output:0]
# [output:1]
# {'info': {'mripl': 'mripl_0', 'proc': 'user_proc_1062871368'},
#  'out': [None, None]}

# %%
# %p
# Out:
# [stdout:0]
# Using matplotlib backend: module://IPython.kernel.zmq.pylab.backend_inline
# Populating the interactive namespace from numpy and matplotlib
# [stdout:1]
# Using matplotlib backend: module://IPython.kernel.zmq.pylab.backend_inline
# Populating the interactive namespace from numpy and matplotlib
# [output:0]
# [output:1]
# Out[0:23]: <matplotlib.collections.PathCollection at 0xa7093ec>
# Out[1:23]: <matplotlib.collections.PathCollection at 0xa23720c>

# %%
# %%px
# for i in range(3):
#     fig,ax = plt.subplots()
#     ax.scatter(r(30),r(30))
# Out:
# [output:0]
# [output:1]

# %%
# %px print 5
# Out:
# [stdout:0] 5
# [stdout:1] 5

# %%
import collections
collections.Counter(range(5)+range(4))
# Out:
# Counter({0: 2, 1: 2, 2: 2, 3: 2, 4: 1})

# %%
a=_

# %%
a.most_common()
# Out:
# [(0, 2), (1, 2), (2, 2), (3, 2), (4, 1)]
